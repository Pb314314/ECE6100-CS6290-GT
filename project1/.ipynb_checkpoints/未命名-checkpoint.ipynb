# %%
def find_first_difference(file1_path, file2_path):
    with open(file1_path, 'r') as file1, open(file2_path, 'r') as file2:
        for line_num, (line1, line2) in enumerate(zip(file1, file2), start=1):
            if line1 != line2:
                return line_num, line1.strip(), line2.strip()
    return None

# %%
file1_path = "./debug_outs/nol2_l1_dm_short_gcc.out"
file2_path = "./pb_out/out.txt"
difference = find_first_difference(file1_path, file2_path)

if difference:
    line_num, line1, line2 = difference
    print(f"First difference found at line {line_num}:")
    print(f"File 1: {line1}")
    print(f"File 2: {line2}")
else:
    print("Files are identical.")
# Out:
# First difference found at line 1:
# File 1: Cache Settings
# File 2: L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,2). LRU. +1 prefetcher. MIP.

# %%
num1 = 0xac1fd6dafe80
hex_str1 = hex(num1)
print("0xac1fd6dafe80 的十六进制表示为:", hex_str1)

num2 = 0x560feb6d7f70
hex_str2 = hex(num2)
print("0x560feb6d7f70 的十六进制表示为:", hex_str2)

num3 = num1 & 0xFFFFFFFFFFC0
num4 = num2 & 0xFFFFFFFFFFC0
# Out:
# 0xac1fd6dafe80 的十六进制表示为: 0xac1fd6dafe80
# 0x560feb6d7f70 的十六进制表示为: 0x560feb6d7f70

# %%
def parse_cache_settings(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    return [l.rstrip("\n") for l in lines if len(l) >= 5]

# Usage:
file_dict = {}
file_path = './pb_out/out.txt'
file_list = parse_cache_settings(file_path)
for i in range(0, len(file_list), 2):
    num_l = file_list[i+1].split()[0]
    file_dict[file_list[i]] = num_l

# %%
file_dict
# Out:
# {' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Prefetcher disabled.': '3.456',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,2). LRU. +1 prefetcher. MIP.': '3.235',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Strided prefetcher. MIP.': '3.358',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,2). LRU. +1 prefetcher. LIP.': '3.230',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Strided prefetcher. LIP.': '3.321',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Prefetcher disabled.': '3.435',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,3). LRU. +1 prefetcher. MIP.': '3.213',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Strided prefetcher. MIP.': '3.330',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,3). LRU. +1 prefetcher. LIP.': '3.207',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Strided prefetcher. LIP.': '3.294',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Prefetcher disabled.': '3.425',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,4). LRU. +1 prefetcher. MIP.': '3.200',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Strided prefetcher. MIP.': '3.317',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,4). LRU. +1 prefetcher. LIP.': '3.197',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Strided prefetcher. LIP.': '3.282',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Prefetcher disabled.': '3.422',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,5). LRU. +1 prefetcher. MIP.': '3.196',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Strided prefetcher. MIP.': '3.314',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,5). LRU. +1 prefetcher. LIP.': '3.194',
#  ' L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Strided prefetcher. LIP.': '3.280',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Prefetcher disabled.': '3.227',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,2). LRU. +1 prefetcher. MIP.': '3.006',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Strided prefetcher. MIP.': '3.135',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,2). LFU. Prefetcher disabled.': '3.228',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,2). LFU. +1 prefetcher. MIP.': '3.004',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,2). LFU. Strided prefetcher. MIP.': '3.103',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,2). LRU. +1 prefetcher. LIP.': '3.000',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Strided prefetcher. LIP.': '3.091',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,2). LFU. +1 prefetcher. LIP.': '3.003',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,2). LFU. Strided prefetcher. LIP.': '3.095',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Prefetcher disabled.': '3.205',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,3). LRU. +1 prefetcher. MIP.': '2.982',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Strided prefetcher. MIP.': '3.103',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,3). LFU. Prefetcher disabled.': '3.203',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,3). LFU. +1 prefetcher. MIP.': '2.974',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,3). LFU. Strided prefetcher. MIP.': '3.062',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,3). LRU. +1 prefetcher. LIP.': '2.977',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Strided prefetcher. LIP.': '3.063',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,3). LFU. +1 prefetcher. LIP.': '2.974',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,3). LFU. Strided prefetcher. LIP.': '3.061',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Prefetcher disabled.': '3.194',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,4). LRU. +1 prefetcher. MIP.': '2.969',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Strided prefetcher. MIP.': '3.087',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,4). LFU. Prefetcher disabled.': '3.196',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,4). LFU. +1 prefetcher. MIP.': '2.967',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,4). LFU. Strided prefetcher. MIP.': '3.050',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,4). LRU. +1 prefetcher. LIP.': '2.966',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Strided prefetcher. LIP.': '3.052',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,4). LFU. +1 prefetcher. LIP.': '2.967',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,4). LFU. Strided prefetcher. LIP.': '3.051',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Prefetcher disabled.': '3.191',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,5). LRU. +1 prefetcher. MIP.': '2.966',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Strided prefetcher. MIP.': '3.086',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,5). LFU. Prefetcher disabled.': '3.192',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,5). LFU. +1 prefetcher. MIP.': '2.963',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,5). LFU. Strided prefetcher. MIP.': '3.046',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,5). LRU. +1 prefetcher. LIP.': '2.963',
#  ' L1 (15,5,1). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Strided prefetcher. LIP.': '3.050',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,5). LFU. +1 prefetcher. LIP.': '2.963',
#  ' L1 (15,5,1). LFU. Prefetcher disabled. L2 (17,5,5). LFU. Strided prefetcher. LIP.': '3.046',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Prefetcher disabled.': '3.055',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,2). LRU. +1 prefetcher. MIP.': '2.838',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Strided prefetcher. MIP.': '2.963',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,2). LFU. Prefetcher disabled.': '3.061',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,2). LFU. +1 prefetcher. MIP.': '2.835',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,2). LFU. Strided prefetcher. MIP.': '2.928',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,2). LRU. +1 prefetcher. LIP.': '2.830',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,2). LRU. Strided prefetcher. LIP.': '2.920',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,2). LFU. +1 prefetcher. LIP.': '2.835',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,2). LFU. Strided prefetcher. LIP.': '2.923',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Prefetcher disabled.': '3.037',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,3). LRU. +1 prefetcher. MIP.': '2.816',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Strided prefetcher. MIP.': '2.939',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,3). LFU. Prefetcher disabled.': '3.046',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,3). LFU. +1 prefetcher. MIP.': '2.816',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,3). LFU. Strided prefetcher. MIP.': '2.902',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,3). LRU. +1 prefetcher. LIP.': '2.808',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Strided prefetcher. LIP.': '2.895',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,3). LFU. +1 prefetcher. LIP.': '2.817',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,3). LFU. Strided prefetcher. LIP.': '2.903',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Prefetcher disabled.': '3.022',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,4). LRU. +1 prefetcher. MIP.': '2.799',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Strided prefetcher. MIP.': '2.923',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,4). LFU. Prefetcher disabled.': '3.039',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,4). LFU. +1 prefetcher. MIP.': '2.809',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,4). LFU. Strided prefetcher. MIP.': '2.893',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,4). LRU. +1 prefetcher. LIP.': '2.794',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Strided prefetcher. LIP.': '2.880',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,4). LFU. +1 prefetcher. LIP.': '2.810',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,4). LFU. Strided prefetcher. LIP.': '2.894',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Prefetcher disabled.': '3.020',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,5). LRU. +1 prefetcher. MIP.': '2.794',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Strided prefetcher. MIP.': '2.919',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,5). LFU. Prefetcher disabled.': '3.036',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,5). LFU. +1 prefetcher. MIP.': '2.807',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,5). LFU. Strided prefetcher. MIP.': '2.890',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,5). LRU. +1 prefetcher. LIP.': '2.792',
#  ' L1 (15,5,2). LRU. Prefetcher disabled. L2 (17,5,5). LRU. Strided prefetcher. LIP.': '2.879',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,5). LFU. +1 prefetcher. LIP.': '2.807',
#  ' L1 (15,5,2). LFU. Prefetcher disabled. L2 (17,5,5). LFU. Strided prefetcher. LIP.': '2.891',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Prefetcher disabled.': '2.998',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,2). LRU. +1 prefetcher. MIP.': '2.882',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Strided prefetcher. MIP.': '2.988',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,2). LRU. +1 prefetcher. LIP.': '2.872',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Strided prefetcher. LIP.': '2.945',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Prefetcher disabled.': '2.974',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,3). LRU. +1 prefetcher. MIP.': '2.858',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Strided prefetcher. MIP.': '2.960',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,3). LRU. +1 prefetcher. LIP.': '2.847',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Strided prefetcher. LIP.': '2.920',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Prefetcher disabled.': '2.963',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,4). LRU. +1 prefetcher. MIP.': '2.848',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Strided prefetcher. MIP.': '2.945',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,4). LRU. +1 prefetcher. LIP.': '2.838',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Strided prefetcher. LIP.': '2.907',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Prefetcher disabled.': '2.957',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,5). LRU. +1 prefetcher. MIP.': '2.842',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Strided prefetcher. MIP.': '2.945',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,5). LRU. +1 prefetcher. LIP.': '2.836',
#  ' L1 (15,6,0). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Strided prefetcher. LIP.': '2.902',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Prefetcher disabled.': '2.771',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,2). LRU. +1 prefetcher. MIP.': '2.659',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Strided prefetcher. MIP.': '2.776',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,2). LFU. Prefetcher disabled.': '2.778',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,2). LFU. +1 prefetcher. MIP.': '2.659',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,2). LFU. Strided prefetcher. MIP.': '2.741',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,2). LRU. +1 prefetcher. LIP.': '2.647',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Strided prefetcher. LIP.': '2.719',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,2). LFU. +1 prefetcher. LIP.': '2.654',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,2). LFU. Strided prefetcher. LIP.': '2.732',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Prefetcher disabled.': '2.746',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,3). LRU. +1 prefetcher. MIP.': '2.629',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Strided prefetcher. MIP.': '2.734',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,3). LFU. Prefetcher disabled.': '2.751',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,3). LFU. +1 prefetcher. MIP.': '2.624',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,3). LFU. Strided prefetcher. MIP.': '2.698',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,3). LRU. +1 prefetcher. LIP.': '2.619',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Strided prefetcher. LIP.': '2.691',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,3). LFU. +1 prefetcher. LIP.': '2.624',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,3). LFU. Strided prefetcher. LIP.': '2.696',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Prefetcher disabled.': '2.735',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,4). LRU. +1 prefetcher. MIP.': '2.620',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Strided prefetcher. MIP.': '2.725',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,4). LFU. Prefetcher disabled.': '2.734',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,4). LFU. +1 prefetcher. MIP.': '2.607',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,4). LFU. Strided prefetcher. MIP.': '2.674',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,4). LRU. +1 prefetcher. LIP.': '2.610',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Strided prefetcher. LIP.': '2.677',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,4). LFU. +1 prefetcher. LIP.': '2.607',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,4). LFU. Strided prefetcher. LIP.': '2.674',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Prefetcher disabled.': '2.730',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,5). LRU. +1 prefetcher. MIP.': '2.616',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Strided prefetcher. MIP.': '2.723',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,5). LFU. Prefetcher disabled.': '2.733',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,5). LFU. +1 prefetcher. MIP.': '2.606',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,5). LFU. Strided prefetcher. MIP.': '2.672',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,5). LRU. +1 prefetcher. LIP.': '2.610',
#  ' L1 (15,6,1). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Strided prefetcher. LIP.': '2.674',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,5). LFU. +1 prefetcher. LIP.': '2.607',
#  ' L1 (15,6,1). LFU. Prefetcher disabled. L2 (17,6,5). LFU. Strided prefetcher. LIP.': '2.673',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Prefetcher disabled.': '2.605',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,2). LRU. +1 prefetcher. MIP.': '2.492',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Strided prefetcher. MIP.': '2.601',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,2). LFU. Prefetcher disabled.': '2.607',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,2). LFU. +1 prefetcher. MIP.': '2.486',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,2). LFU. Strided prefetcher. MIP.': '2.559',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,2). LRU. +1 prefetcher. LIP.': '2.481',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,2). LRU. Strided prefetcher. LIP.': '2.554',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,2). LFU. +1 prefetcher. LIP.': '2.484',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,2). LFU. Strided prefetcher. LIP.': '2.554',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Prefetcher disabled.': '2.581',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,3). LRU. +1 prefetcher. MIP.': '2.465',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Strided prefetcher. MIP.': '2.575',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,3). LFU. Prefetcher disabled.': '2.594',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,3). LFU. +1 prefetcher. MIP.': '2.468',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,3). LFU. Strided prefetcher. MIP.': '2.539',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,3). LRU. +1 prefetcher. LIP.': '2.453',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,3). LRU. Strided prefetcher. LIP.': '2.527',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,3). LFU. +1 prefetcher. LIP.': '2.469',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,3). LFU. Strided prefetcher. LIP.': '2.539',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Prefetcher disabled.': '2.568',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,4). LRU. +1 prefetcher. MIP.': '2.453',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Strided prefetcher. MIP.': '2.556',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,4). LFU. Prefetcher disabled.': '2.582',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,4). LFU. +1 prefetcher. MIP.': '2.455',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,4). LFU. Strided prefetcher. MIP.': '2.521',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,4). LRU. +1 prefetcher. LIP.': '2.443',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,4). LRU. Strided prefetcher. LIP.': '2.510',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,4). LFU. +1 prefetcher. LIP.': '2.455',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,4). LFU. Strided prefetcher. LIP.': '2.521',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Prefetcher disabled.': '2.563',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,5). LRU. +1 prefetcher. MIP.': '2.450',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Strided prefetcher. MIP.': '2.558',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,5). LFU. Prefetcher disabled.': '2.580',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,5). LFU. +1 prefetcher. MIP.': '2.453',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,5). LFU. Strided prefetcher. MIP.': '2.520',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,5). LRU. +1 prefetcher. LIP.': '2.441',
#  ' L1 (15,6,2). LRU. Prefetcher disabled. L2 (17,6,5). LRU. Strided prefetcher. LIP.': '2.506',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,5). LFU. +1 prefetcher. LIP.': '2.454',
#  ' L1 (15,6,2). LFU. Prefetcher disabled. L2 (17,6,5). LFU. Strided prefetcher. LIP.': '2.520',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Prefetcher disabled.': '2.706',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,2). LRU. +1 prefetcher. MIP.': '2.658',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Strided prefetcher. MIP.': '2.757',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,2). LRU. +1 prefetcher. LIP.': '2.642',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Strided prefetcher. LIP.': '2.696',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Prefetcher disabled.': '2.675',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,3). LRU. +1 prefetcher. MIP.': '2.617',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Strided prefetcher. MIP.': '2.703',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,3). LRU. +1 prefetcher. LIP.': '2.607',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Strided prefetcher. LIP.': '2.655',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Prefetcher disabled.': '2.664',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,4). LRU. +1 prefetcher. MIP.': '2.605',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Strided prefetcher. MIP.': '2.680',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,4). LRU. +1 prefetcher. LIP.': '2.596',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Strided prefetcher. LIP.': '2.641',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Prefetcher disabled.': '2.662',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,5). LRU. +1 prefetcher. MIP.': '2.603',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Strided prefetcher. MIP.': '2.671',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,5). LRU. +1 prefetcher. LIP.': '2.599',
#  ' L1 (15,7,0). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Strided prefetcher. LIP.': '2.638',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Prefetcher disabled.': '2.485',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,2). LRU. +1 prefetcher. MIP.': '2.441',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Strided prefetcher. MIP.': '2.542',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,2). LFU. Prefetcher disabled.': '2.499',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,2). LFU. +1 prefetcher. MIP.': '2.437',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,2). LFU. Strided prefetcher. MIP.': '2.504',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,2). LRU. +1 prefetcher. LIP.': '2.423',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Strided prefetcher. LIP.': '2.477',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,2). LFU. +1 prefetcher. LIP.': '2.437',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,2). LFU. Strided prefetcher. LIP.': '2.490',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Prefetcher disabled.': '2.453',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,3). LRU. +1 prefetcher. MIP.': '2.395',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Strided prefetcher. MIP.': '2.484',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,3). LFU. Prefetcher disabled.': '2.461',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,3). LFU. +1 prefetcher. MIP.': '2.393',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,3). LFU. Strided prefetcher. MIP.': '2.448',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,3). LRU. +1 prefetcher. LIP.': '2.385',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Strided prefetcher. LIP.': '2.433',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,3). LFU. +1 prefetcher. LIP.': '2.395',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,3). LFU. Strided prefetcher. LIP.': '2.445',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Prefetcher disabled.': '2.442',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,4). LRU. +1 prefetcher. MIP.': '2.385',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Strided prefetcher. MIP.': '2.460',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,4). LFU. Prefetcher disabled.': '2.442',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,4). LFU. +1 prefetcher. MIP.': '2.373',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,4). LFU. Strided prefetcher. MIP.': '2.421',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,4). LRU. +1 prefetcher. LIP.': '2.374',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Strided prefetcher. LIP.': '2.419',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,4). LFU. +1 prefetcher. LIP.': '2.373',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,4). LFU. Strided prefetcher. LIP.': '2.421',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Prefetcher disabled.': '2.441',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,5). LRU. +1 prefetcher. MIP.': '2.385',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Strided prefetcher. MIP.': '2.456',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,5). LFU. Prefetcher disabled.': '2.437',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,5). LFU. +1 prefetcher. MIP.': '2.371',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,5). LFU. Strided prefetcher. MIP.': '2.419',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,5). LRU. +1 prefetcher. LIP.': '2.377',
#  ' L1 (15,7,1). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Strided prefetcher. LIP.': '2.418',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,5). LFU. +1 prefetcher. LIP.': '2.372',
#  ' L1 (15,7,1). LFU. Prefetcher disabled. L2 (17,7,5). LFU. Strided prefetcher. LIP.': '2.418',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Prefetcher disabled.': '2.317',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,2). LRU. +1 prefetcher. MIP.': '2.273',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Strided prefetcher. MIP.': '2.365',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,2). LFU. Prefetcher disabled.': '2.326',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,2). LFU. +1 prefetcher. MIP.': '2.265',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,2). LFU. Strided prefetcher. MIP.': '2.322',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,2). LRU. +1 prefetcher. LIP.': '2.256',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,2). LRU. Strided prefetcher. LIP.': '2.310',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,2). LFU. +1 prefetcher. LIP.': '2.265',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,2). LFU. Strided prefetcher. LIP.': '2.312',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Prefetcher disabled.': '2.287',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,3). LRU. +1 prefetcher. MIP.': '2.233',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Strided prefetcher. MIP.': '2.324',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,3). LFU. Prefetcher disabled.': '2.309',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,3). LFU. +1 prefetcher. MIP.': '2.241',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,3). LFU. Strided prefetcher. MIP.': '2.290',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,3). LRU. +1 prefetcher. LIP.': '2.220',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,3). LRU. Strided prefetcher. LIP.': '2.269',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,3). LFU. +1 prefetcher. LIP.': '2.242',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,3). LFU. Strided prefetcher. LIP.': '2.289',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Prefetcher disabled.': '2.275',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,4). LRU. +1 prefetcher. MIP.': '2.217',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Strided prefetcher. MIP.': '2.296',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,4). LFU. Prefetcher disabled.': '2.297',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,4). LFU. +1 prefetcher. MIP.': '2.230',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,4). LFU. Strided prefetcher. MIP.': '2.276',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,4). LRU. +1 prefetcher. LIP.': '2.207',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,4). LRU. Strided prefetcher. LIP.': '2.252',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,4). LFU. +1 prefetcher. LIP.': '2.231',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,4). LFU. Strided prefetcher. LIP.': '2.274',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Prefetcher disabled.': '2.274',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,5). LRU. +1 prefetcher. MIP.': '2.217',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Strided prefetcher. MIP.': '2.283',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,5). LFU. Prefetcher disabled.': '2.297',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,5). LFU. +1 prefetcher. MIP.': '2.232',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,5). LFU. Strided prefetcher. MIP.': '2.274',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,5). LRU. +1 prefetcher. LIP.': '2.211',
#  ' L1 (15,7,2). LRU. Prefetcher disabled. L2 (17,7,5). LRU. Strided prefetcher. LIP.': '2.251',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,5). LFU. +1 prefetcher. LIP.': '2.232',
#  ' L1 (15,7,2). LFU. Prefetcher disabled. L2 (17,7,5). LFU. Strided prefetcher. LIP.': '2.272'}

# %%
def parse_string(data_str):
    # Initialize a dictionary to hold the parsed values
    parsed_values = {
        'c1': None,
        'b1': None,
        's1': None,
        'c2': None,
        'b2': None,
        's2': None,
        'prefetch': None,
        'rp': None,
        'IP': None,
    }
    
    # Split the string by ". " to separate the sections
    sections = data_str.split('. ')
    
    # Extract values for c1, b1, s1 from the first section
    l1_values = sections[0].split('(')[1].split(')')[0].split(',')
    parsed_values['c1'] = int(l1_values[0])
    parsed_values['b1'] = int(l1_values[1])
    parsed_values['s1'] = int(l1_values[2])
    
    # Extract the replacement policy (rp) from the second section
    parsed_values['rp'] = sections[1].split('.')[0]
    
    # Extract values for c2, b2, s2 from the third section
    l2_values = sections[3].split('(')[1].split(')')[0].split(',')
    parsed_values['c2'] = int(l2_values[0])
    parsed_values['b2'] = int(l2_values[1])
    parsed_values['s2'] = int(l2_values[2])
    
    # Extract prefetch value
    prefetch_value = sections[5]
    parsed_values['prefetch'] = sections[5]
    
    # Extract IP from the last section
    parsed_values['IP'] = sections[-1]
    
    return parsed_values

# Test the function with the provided string

data_list = []
for line in file_dict.keys():
    parsed_data = [l for l in parse_string(line).values()]
    parsed_data.append(file_dict[line])
    data_list.append(parsed_data)

# %%
s = "L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,3). LRU. Strided prefetcher. MIP."
parse_string(s)
s2 = "L1 (15,5,0). LRU. Prefetcher disabled. L2 (17,5,4). LRU. Prefetcher disabled."
parse_string(s2)
# Out:
# {'c1': 15,
#  'b1': 5,
#  's1': 0,
#  'c2': 17,
#  'b2': 5,
#  's2': 4,
#  'prefetch': 'Prefetcher disabled.',
#  'rp': 'LRU',
#  'IP': 'Prefetcher disabled.'}

# %%
data_list[10]
# Out:
# [15,
#  5,
#  0,
#  17,
#  5,
#  4,
#  'Prefetcher disabled.',
#  'LRU',
#  'Prefetcher disabled.',
#  '3.425']

# %%
from prettytable import PrettyTable

# Assuming your list of lists is structured like the given example

# Create a PrettyTable object
table = PrettyTable()

sorted_data_lists_by_last_element = sorted(data_list, key=lambda x: x[-1])

# Set column names based on the number of elements in the first list
column_names = [f"Column {i+1}" for i in range(len(data_list[0]))]
column_names = ["C1","B1", "S1","C2","B2","S2","Prefetch Policy","Replacement Policy","Insertion Policy","L1_AAT"]
table.field_names = column_names

# Add each list as a row in the table
for one_line in sorted_data_lists_by_last_element[:30]:
    table.add_row(one_line)

# Print the table
print(table)
# Out:
# +----+----+----+----+----+----+----------------------+--------------------+----------------------+-------+
# | C1 | B1 | S1 | C2 | B2 | S2 |   Prefetch Policy    | Replacement Policy |   Insertion Policy   |  AAT  |
# +----+----+----+----+----+----+----------------------+--------------------+----------------------+-------+
# | 15 | 7  | 2  | 17 | 7  | 4  |    +1 prefetcher     |        LRU         |         LIP.         | 2.207 |
# | 15 | 7  | 2  | 17 | 7  | 5  |    +1 prefetcher     |        LRU         |         LIP.         | 2.211 |
# | 15 | 7  | 2  | 17 | 7  | 4  |    +1 prefetcher     |        LRU         |         MIP.         | 2.217 |
# | 15 | 7  | 2  | 17 | 7  | 5  |    +1 prefetcher     |        LRU         |         MIP.         | 2.217 |
# | 15 | 7  | 2  | 17 | 7  | 3  |    +1 prefetcher     |        LRU         |         LIP.         | 2.220 |
# | 15 | 7  | 2  | 17 | 7  | 4  |    +1 prefetcher     |        LFU         |         MIP.         | 2.230 |
# | 15 | 7  | 2  | 17 | 7  | 4  |    +1 prefetcher     |        LFU         |         LIP.         | 2.231 |
# | 15 | 7  | 2  | 17 | 7  | 5  |    +1 prefetcher     |        LFU         |         MIP.         | 2.232 |
# | 15 | 7  | 2  | 17 | 7  | 5  |    +1 prefetcher     |        LFU         |         LIP.         | 2.232 |
# | 15 | 7  | 2  | 17 | 7  | 3  |    +1 prefetcher     |        LRU         |         MIP.         | 2.233 |
# | 15 | 7  | 2  | 17 | 7  | 3  |    +1 prefetcher     |        LFU         |         MIP.         | 2.241 |
# | 15 | 7  | 2  | 17 | 7  | 3  |    +1 prefetcher     |        LFU         |         LIP.         | 2.242 |
# | 15 | 7  | 2  | 17 | 7  | 5  |  Strided prefetcher  |        LRU         |         LIP.         | 2.251 |
# | 15 | 7  | 2  | 17 | 7  | 4  |  Strided prefetcher  |        LRU         |         LIP.         | 2.252 |
# | 15 | 7  | 2  | 17 | 7  | 2  |    +1 prefetcher     |        LRU         |         LIP.         | 2.256 |
# | 15 | 7  | 2  | 17 | 7  | 2  |    +1 prefetcher     |        LFU         |         MIP.         | 2.265 |
# | 15 | 7  | 2  | 17 | 7  | 2  |    +1 prefetcher     |        LFU         |         LIP.         | 2.265 |
# | 15 | 7  | 2  | 17 | 7  | 3  |  Strided prefetcher  |        LRU         |         LIP.         | 2.269 |
# | 15 | 7  | 2  | 17 | 7  | 5  |  Strided prefetcher  |        LFU         |         LIP.         | 2.272 |
# | 15 | 7  | 2  | 17 | 7  | 2  |    +1 prefetcher     |        LRU         |         MIP.         | 2.273 |
# | 15 | 7  | 2  | 17 | 7  | 4  |  Strided prefetcher  |        LFU         |         LIP.         | 2.274 |
# | 15 | 7  | 2  | 17 | 7  | 5  | Prefetcher disabled. |        LRU         | Prefetcher disabled. | 2.274 |
# | 15 | 7  | 2  | 17 | 7  | 5  |  Strided prefetcher  |        LFU         |         MIP.         | 2.274 |
# | 15 | 7  | 2  | 17 | 7  | 4  | Prefetcher disabled. |        LRU         | Prefetcher disabled. | 2.275 |
# | 15 | 7  | 2  | 17 | 7  | 4  |  Strided prefetcher  |        LFU         |         MIP.         | 2.276 |
# | 15 | 7  | 2  | 17 | 7  | 5  |  Strided prefetcher  |        LRU         |         MIP.         | 2.283 |
# | 15 | 7  | 2  | 17 | 7  | 3  | Prefetcher disabled. |        LRU         | Prefetcher disabled. | 2.287 |
# | 15 | 7  | 2  | 17 | 7  | 3  |  Strided prefetcher  |        LFU         |         LIP.         | 2.289 |
# | 15 | 7  | 2  | 17 | 7  | 3  |  Strided prefetcher  |        LFU         |         MIP.         | 2.290 |
# | 15 | 7  | 2  | 17 | 7  | 4  |  Strided prefetcher  |        LRU         |         MIP.         | 2.296 |
# +----+----+----+----+----+----+----------------------+--------------------+----------------------+-------+

# %%
sorted(data_list, key=lambda x: x[-1])
# Out:
# [[15, 7, 2, 17, 7, 4, '+1 prefetcher', 'LRU', 'LIP.', '2.207'],
#  [15, 7, 2, 17, 7, 5, '+1 prefetcher', 'LRU', 'LIP.', '2.211'],
#  [15, 7, 2, 17, 7, 4, '+1 prefetcher', 'LRU', 'MIP.', '2.217'],
#  [15, 7, 2, 17, 7, 5, '+1 prefetcher', 'LRU', 'MIP.', '2.217'],
#  [15, 7, 2, 17, 7, 3, '+1 prefetcher', 'LRU', 'LIP.', '2.220'],
#  [15, 7, 2, 17, 7, 4, '+1 prefetcher', 'LFU', 'MIP.', '2.230'],
#  [15, 7, 2, 17, 7, 4, '+1 prefetcher', 'LFU', 'LIP.', '2.231'],
#  [15, 7, 2, 17, 7, 5, '+1 prefetcher', 'LFU', 'MIP.', '2.232'],
#  [15, 7, 2, 17, 7, 5, '+1 prefetcher', 'LFU', 'LIP.', '2.232'],
#  [15, 7, 2, 17, 7, 3, '+1 prefetcher', 'LRU', 'MIP.', '2.233'],
#  [15, 7, 2, 17, 7, 3, '+1 prefetcher', 'LFU', 'MIP.', '2.241'],
#  [15, 7, 2, 17, 7, 3, '+1 prefetcher', 'LFU', 'LIP.', '2.242'],
#  [15, 7, 2, 17, 7, 5, 'Strided prefetcher', 'LRU', 'LIP.', '2.251'],
#  [15, 7, 2, 17, 7, 4, 'Strided prefetcher', 'LRU', 'LIP.', '2.252'],
#  [15, 7, 2, 17, 7, 2, '+1 prefetcher', 'LRU', 'LIP.', '2.256'],
#  [15, 7, 2, 17, 7, 2, '+1 prefetcher', 'LFU', 'MIP.', '2.265'],
#  [15, 7, 2, 17, 7, 2, '+1 prefetcher', 'LFU', 'LIP.', '2.265'],
#  [15, 7, 2, 17, 7, 3, 'Strided prefetcher', 'LRU', 'LIP.', '2.269'],
#  [15, 7, 2, 17, 7, 5, 'Strided prefetcher', 'LFU', 'LIP.', '2.272'],
#  [15, 7, 2, 17, 7, 2, '+1 prefetcher', 'LRU', 'MIP.', '2.273'],
#  [15, 7, 2, 17, 7, 4, 'Strided prefetcher', 'LFU', 'LIP.', '2.274'],
#  [15,
#   7,
#   2,
#   17,
#   7,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.274'],
#  [15, 7, 2, 17, 7, 5, 'Strided prefetcher', 'LFU', 'MIP.', '2.274'],
#  [15,
#   7,
#   2,
#   17,
#   7,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.275'],
#  [15, 7, 2, 17, 7, 4, 'Strided prefetcher', 'LFU', 'MIP.', '2.276'],
#  [15, 7, 2, 17, 7, 5, 'Strided prefetcher', 'LRU', 'MIP.', '2.283'],
#  [15,
#   7,
#   2,
#   17,
#   7,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.287'],
#  [15, 7, 2, 17, 7, 3, 'Strided prefetcher', 'LFU', 'LIP.', '2.289'],
#  [15, 7, 2, 17, 7, 3, 'Strided prefetcher', 'LFU', 'MIP.', '2.290'],
#  [15, 7, 2, 17, 7, 4, 'Strided prefetcher', 'LRU', 'MIP.', '2.296'],
#  [15,
#   7,
#   2,
#   17,
#   7,
#   4,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.297'],
#  [15,
#   7,
#   2,
#   17,
#   7,
#   5,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.297'],
#  [15,
#   7,
#   2,
#   17,
#   7,
#   3,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.309'],
#  [15, 7, 2, 17, 7, 2, 'Strided prefetcher', 'LRU', 'LIP.', '2.310'],
#  [15, 7, 2, 17, 7, 2, 'Strided prefetcher', 'LFU', 'LIP.', '2.312'],
#  [15,
#   7,
#   2,
#   17,
#   7,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.317'],
#  [15, 7, 2, 17, 7, 2, 'Strided prefetcher', 'LFU', 'MIP.', '2.322'],
#  [15, 7, 2, 17, 7, 3, 'Strided prefetcher', 'LRU', 'MIP.', '2.324'],
#  [15,
#   7,
#   2,
#   17,
#   7,
#   2,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.326'],
#  [15, 7, 2, 17, 7, 2, 'Strided prefetcher', 'LRU', 'MIP.', '2.365'],
#  [15, 7, 1, 17, 7, 5, '+1 prefetcher', 'LFU', 'MIP.', '2.371'],
#  [15, 7, 1, 17, 7, 5, '+1 prefetcher', 'LFU', 'LIP.', '2.372'],
#  [15, 7, 1, 17, 7, 4, '+1 prefetcher', 'LFU', 'MIP.', '2.373'],
#  [15, 7, 1, 17, 7, 4, '+1 prefetcher', 'LFU', 'LIP.', '2.373'],
#  [15, 7, 1, 17, 7, 4, '+1 prefetcher', 'LRU', 'LIP.', '2.374'],
#  [15, 7, 1, 17, 7, 5, '+1 prefetcher', 'LRU', 'LIP.', '2.377'],
#  [15, 7, 1, 17, 7, 3, '+1 prefetcher', 'LRU', 'LIP.', '2.385'],
#  [15, 7, 1, 17, 7, 4, '+1 prefetcher', 'LRU', 'MIP.', '2.385'],
#  [15, 7, 1, 17, 7, 5, '+1 prefetcher', 'LRU', 'MIP.', '2.385'],
#  [15, 7, 1, 17, 7, 3, '+1 prefetcher', 'LFU', 'MIP.', '2.393'],
#  [15, 7, 1, 17, 7, 3, '+1 prefetcher', 'LRU', 'MIP.', '2.395'],
#  [15, 7, 1, 17, 7, 3, '+1 prefetcher', 'LFU', 'LIP.', '2.395'],
#  [15, 7, 1, 17, 7, 5, 'Strided prefetcher', 'LRU', 'LIP.', '2.418'],
#  [15, 7, 1, 17, 7, 5, 'Strided prefetcher', 'LFU', 'LIP.', '2.418'],
#  [15, 7, 1, 17, 7, 4, 'Strided prefetcher', 'LRU', 'LIP.', '2.419'],
#  [15, 7, 1, 17, 7, 5, 'Strided prefetcher', 'LFU', 'MIP.', '2.419'],
#  [15, 7, 1, 17, 7, 4, 'Strided prefetcher', 'LFU', 'MIP.', '2.421'],
#  [15, 7, 1, 17, 7, 4, 'Strided prefetcher', 'LFU', 'LIP.', '2.421'],
#  [15, 7, 1, 17, 7, 2, '+1 prefetcher', 'LRU', 'LIP.', '2.423'],
#  [15, 7, 1, 17, 7, 3, 'Strided prefetcher', 'LRU', 'LIP.', '2.433'],
#  [15, 7, 1, 17, 7, 2, '+1 prefetcher', 'LFU', 'MIP.', '2.437'],
#  [15, 7, 1, 17, 7, 2, '+1 prefetcher', 'LFU', 'LIP.', '2.437'],
#  [15,
#   7,
#   1,
#   17,
#   7,
#   5,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.437'],
#  [15, 6, 2, 17, 6, 5, '+1 prefetcher', 'LRU', 'LIP.', '2.441'],
#  [15, 7, 1, 17, 7, 2, '+1 prefetcher', 'LRU', 'MIP.', '2.441'],
#  [15,
#   7,
#   1,
#   17,
#   7,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.441'],
#  [15,
#   7,
#   1,
#   17,
#   7,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.442'],
#  [15,
#   7,
#   1,
#   17,
#   7,
#   4,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.442'],
#  [15, 6, 2, 17, 6, 4, '+1 prefetcher', 'LRU', 'LIP.', '2.443'],
#  [15, 7, 1, 17, 7, 3, 'Strided prefetcher', 'LFU', 'LIP.', '2.445'],
#  [15, 7, 1, 17, 7, 3, 'Strided prefetcher', 'LFU', 'MIP.', '2.448'],
#  [15, 6, 2, 17, 6, 5, '+1 prefetcher', 'LRU', 'MIP.', '2.450'],
#  [15, 6, 2, 17, 6, 3, '+1 prefetcher', 'LRU', 'LIP.', '2.453'],
#  [15, 6, 2, 17, 6, 4, '+1 prefetcher', 'LRU', 'MIP.', '2.453'],
#  [15, 6, 2, 17, 6, 5, '+1 prefetcher', 'LFU', 'MIP.', '2.453'],
#  [15,
#   7,
#   1,
#   17,
#   7,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.453'],
#  [15, 6, 2, 17, 6, 5, '+1 prefetcher', 'LFU', 'LIP.', '2.454'],
#  [15, 6, 2, 17, 6, 4, '+1 prefetcher', 'LFU', 'MIP.', '2.455'],
#  [15, 6, 2, 17, 6, 4, '+1 prefetcher', 'LFU', 'LIP.', '2.455'],
#  [15, 7, 1, 17, 7, 5, 'Strided prefetcher', 'LRU', 'MIP.', '2.456'],
#  [15, 7, 1, 17, 7, 4, 'Strided prefetcher', 'LRU', 'MIP.', '2.460'],
#  [15,
#   7,
#   1,
#   17,
#   7,
#   3,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.461'],
#  [15, 6, 2, 17, 6, 3, '+1 prefetcher', 'LRU', 'MIP.', '2.465'],
#  [15, 6, 2, 17, 6, 3, '+1 prefetcher', 'LFU', 'MIP.', '2.468'],
#  [15, 6, 2, 17, 6, 3, '+1 prefetcher', 'LFU', 'LIP.', '2.469'],
#  [15, 7, 1, 17, 7, 2, 'Strided prefetcher', 'LRU', 'LIP.', '2.477'],
#  [15, 6, 2, 17, 6, 2, '+1 prefetcher', 'LRU', 'LIP.', '2.481'],
#  [15, 6, 2, 17, 6, 2, '+1 prefetcher', 'LFU', 'LIP.', '2.484'],
#  [15, 7, 1, 17, 7, 3, 'Strided prefetcher', 'LRU', 'MIP.', '2.484'],
#  [15,
#   7,
#   1,
#   17,
#   7,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.485'],
#  [15, 6, 2, 17, 6, 2, '+1 prefetcher', 'LFU', 'MIP.', '2.486'],
#  [15, 7, 1, 17, 7, 2, 'Strided prefetcher', 'LFU', 'LIP.', '2.490'],
#  [15, 6, 2, 17, 6, 2, '+1 prefetcher', 'LRU', 'MIP.', '2.492'],
#  [15,
#   7,
#   1,
#   17,
#   7,
#   2,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.499'],
#  [15, 7, 1, 17, 7, 2, 'Strided prefetcher', 'LFU', 'MIP.', '2.504'],
#  [15, 6, 2, 17, 6, 5, 'Strided prefetcher', 'LRU', 'LIP.', '2.506'],
#  [15, 6, 2, 17, 6, 4, 'Strided prefetcher', 'LRU', 'LIP.', '2.510'],
#  [15, 6, 2, 17, 6, 5, 'Strided prefetcher', 'LFU', 'MIP.', '2.520'],
#  [15, 6, 2, 17, 6, 5, 'Strided prefetcher', 'LFU', 'LIP.', '2.520'],
#  [15, 6, 2, 17, 6, 4, 'Strided prefetcher', 'LFU', 'MIP.', '2.521'],
#  [15, 6, 2, 17, 6, 4, 'Strided prefetcher', 'LFU', 'LIP.', '2.521'],
#  [15, 6, 2, 17, 6, 3, 'Strided prefetcher', 'LRU', 'LIP.', '2.527'],
#  [15, 6, 2, 17, 6, 3, 'Strided prefetcher', 'LFU', 'MIP.', '2.539'],
#  [15, 6, 2, 17, 6, 3, 'Strided prefetcher', 'LFU', 'LIP.', '2.539'],
#  [15, 7, 1, 17, 7, 2, 'Strided prefetcher', 'LRU', 'MIP.', '2.542'],
#  [15, 6, 2, 17, 6, 2, 'Strided prefetcher', 'LRU', 'LIP.', '2.554'],
#  [15, 6, 2, 17, 6, 2, 'Strided prefetcher', 'LFU', 'LIP.', '2.554'],
#  [15, 6, 2, 17, 6, 4, 'Strided prefetcher', 'LRU', 'MIP.', '2.556'],
#  [15, 6, 2, 17, 6, 5, 'Strided prefetcher', 'LRU', 'MIP.', '2.558'],
#  [15, 6, 2, 17, 6, 2, 'Strided prefetcher', 'LFU', 'MIP.', '2.559'],
#  [15,
#   6,
#   2,
#   17,
#   6,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.563'],
#  [15,
#   6,
#   2,
#   17,
#   6,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.568'],
#  [15, 6, 2, 17, 6, 3, 'Strided prefetcher', 'LRU', 'MIP.', '2.575'],
#  [15,
#   6,
#   2,
#   17,
#   6,
#   5,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.580'],
#  [15,
#   6,
#   2,
#   17,
#   6,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.581'],
#  [15,
#   6,
#   2,
#   17,
#   6,
#   4,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.582'],
#  [15,
#   6,
#   2,
#   17,
#   6,
#   3,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.594'],
#  [15, 7, 0, 17, 7, 4, '+1 prefetcher', 'LRU', 'LIP.', '2.596'],
#  [15, 7, 0, 17, 7, 5, '+1 prefetcher', 'LRU', 'LIP.', '2.599'],
#  [15, 6, 2, 17, 6, 2, 'Strided prefetcher', 'LRU', 'MIP.', '2.601'],
#  [15, 7, 0, 17, 7, 5, '+1 prefetcher', 'LRU', 'MIP.', '2.603'],
#  [15,
#   6,
#   2,
#   17,
#   6,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.605'],
#  [15, 7, 0, 17, 7, 4, '+1 prefetcher', 'LRU', 'MIP.', '2.605'],
#  [15, 6, 1, 17, 6, 5, '+1 prefetcher', 'LFU', 'MIP.', '2.606'],
#  [15, 6, 1, 17, 6, 4, '+1 prefetcher', 'LFU', 'MIP.', '2.607'],
#  [15, 6, 1, 17, 6, 4, '+1 prefetcher', 'LFU', 'LIP.', '2.607'],
#  [15, 6, 1, 17, 6, 5, '+1 prefetcher', 'LFU', 'LIP.', '2.607'],
#  [15,
#   6,
#   2,
#   17,
#   6,
#   2,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.607'],
#  [15, 7, 0, 17, 7, 3, '+1 prefetcher', 'LRU', 'LIP.', '2.607'],
#  [15, 6, 1, 17, 6, 4, '+1 prefetcher', 'LRU', 'LIP.', '2.610'],
#  [15, 6, 1, 17, 6, 5, '+1 prefetcher', 'LRU', 'LIP.', '2.610'],
#  [15, 6, 1, 17, 6, 5, '+1 prefetcher', 'LRU', 'MIP.', '2.616'],
#  [15, 7, 0, 17, 7, 3, '+1 prefetcher', 'LRU', 'MIP.', '2.617'],
#  [15, 6, 1, 17, 6, 3, '+1 prefetcher', 'LRU', 'LIP.', '2.619'],
#  [15, 6, 1, 17, 6, 4, '+1 prefetcher', 'LRU', 'MIP.', '2.620'],
#  [15, 6, 1, 17, 6, 3, '+1 prefetcher', 'LFU', 'MIP.', '2.624'],
#  [15, 6, 1, 17, 6, 3, '+1 prefetcher', 'LFU', 'LIP.', '2.624'],
#  [15, 6, 1, 17, 6, 3, '+1 prefetcher', 'LRU', 'MIP.', '2.629'],
#  [15, 7, 0, 17, 7, 5, 'Strided prefetcher', 'LRU', 'LIP.', '2.638'],
#  [15, 7, 0, 17, 7, 4, 'Strided prefetcher', 'LRU', 'LIP.', '2.641'],
#  [15, 7, 0, 17, 7, 2, '+1 prefetcher', 'LRU', 'LIP.', '2.642'],
#  [15, 6, 1, 17, 6, 2, '+1 prefetcher', 'LRU', 'LIP.', '2.647'],
#  [15, 6, 1, 17, 6, 2, '+1 prefetcher', 'LFU', 'LIP.', '2.654'],
#  [15, 7, 0, 17, 7, 3, 'Strided prefetcher', 'LRU', 'LIP.', '2.655'],
#  [15, 7, 0, 17, 7, 2, '+1 prefetcher', 'LRU', 'MIP.', '2.658'],
#  [15, 6, 1, 17, 6, 2, '+1 prefetcher', 'LRU', 'MIP.', '2.659'],
#  [15, 6, 1, 17, 6, 2, '+1 prefetcher', 'LFU', 'MIP.', '2.659'],
#  [15,
#   7,
#   0,
#   17,
#   7,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.662'],
#  [15,
#   7,
#   0,
#   17,
#   7,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.664'],
#  [15, 7, 0, 17, 7, 5, 'Strided prefetcher', 'LRU', 'MIP.', '2.671'],
#  [15, 6, 1, 17, 6, 5, 'Strided prefetcher', 'LFU', 'MIP.', '2.672'],
#  [15, 6, 1, 17, 6, 5, 'Strided prefetcher', 'LFU', 'LIP.', '2.673'],
#  [15, 6, 1, 17, 6, 4, 'Strided prefetcher', 'LFU', 'MIP.', '2.674'],
#  [15, 6, 1, 17, 6, 4, 'Strided prefetcher', 'LFU', 'LIP.', '2.674'],
#  [15, 6, 1, 17, 6, 5, 'Strided prefetcher', 'LRU', 'LIP.', '2.674'],
#  [15,
#   7,
#   0,
#   17,
#   7,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.675'],
#  [15, 6, 1, 17, 6, 4, 'Strided prefetcher', 'LRU', 'LIP.', '2.677'],
#  [15, 7, 0, 17, 7, 4, 'Strided prefetcher', 'LRU', 'MIP.', '2.680'],
#  [15, 6, 1, 17, 6, 3, 'Strided prefetcher', 'LRU', 'LIP.', '2.691'],
#  [15, 6, 1, 17, 6, 3, 'Strided prefetcher', 'LFU', 'LIP.', '2.696'],
#  [15, 7, 0, 17, 7, 2, 'Strided prefetcher', 'LRU', 'LIP.', '2.696'],
#  [15, 6, 1, 17, 6, 3, 'Strided prefetcher', 'LFU', 'MIP.', '2.698'],
#  [15, 7, 0, 17, 7, 3, 'Strided prefetcher', 'LRU', 'MIP.', '2.703'],
#  [15,
#   7,
#   0,
#   17,
#   7,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.706'],
#  [15, 6, 1, 17, 6, 2, 'Strided prefetcher', 'LRU', 'LIP.', '2.719'],
#  [15, 6, 1, 17, 6, 5, 'Strided prefetcher', 'LRU', 'MIP.', '2.723'],
#  [15, 6, 1, 17, 6, 4, 'Strided prefetcher', 'LRU', 'MIP.', '2.725'],
#  [15,
#   6,
#   1,
#   17,
#   6,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.730'],
#  [15, 6, 1, 17, 6, 2, 'Strided prefetcher', 'LFU', 'LIP.', '2.732'],
#  [15,
#   6,
#   1,
#   17,
#   6,
#   5,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.733'],
#  [15, 6, 1, 17, 6, 3, 'Strided prefetcher', 'LRU', 'MIP.', '2.734'],
#  [15,
#   6,
#   1,
#   17,
#   6,
#   4,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.734'],
#  [15,
#   6,
#   1,
#   17,
#   6,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.735'],
#  [15, 6, 1, 17, 6, 2, 'Strided prefetcher', 'LFU', 'MIP.', '2.741'],
#  [15,
#   6,
#   1,
#   17,
#   6,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.746'],
#  [15,
#   6,
#   1,
#   17,
#   6,
#   3,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.751'],
#  [15, 7, 0, 17, 7, 2, 'Strided prefetcher', 'LRU', 'MIP.', '2.757'],
#  [15,
#   6,
#   1,
#   17,
#   6,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.771'],
#  [15, 6, 1, 17, 6, 2, 'Strided prefetcher', 'LRU', 'MIP.', '2.776'],
#  [15,
#   6,
#   1,
#   17,
#   6,
#   2,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '2.778'],
#  [15, 5, 2, 17, 5, 5, '+1 prefetcher', 'LRU', 'LIP.', '2.792'],
#  [15, 5, 2, 17, 5, 4, '+1 prefetcher', 'LRU', 'LIP.', '2.794'],
#  [15, 5, 2, 17, 5, 5, '+1 prefetcher', 'LRU', 'MIP.', '2.794'],
#  [15, 5, 2, 17, 5, 4, '+1 prefetcher', 'LRU', 'MIP.', '2.799'],
#  [15, 5, 2, 17, 5, 5, '+1 prefetcher', 'LFU', 'MIP.', '2.807'],
#  [15, 5, 2, 17, 5, 5, '+1 prefetcher', 'LFU', 'LIP.', '2.807'],
#  [15, 5, 2, 17, 5, 3, '+1 prefetcher', 'LRU', 'LIP.', '2.808'],
#  [15, 5, 2, 17, 5, 4, '+1 prefetcher', 'LFU', 'MIP.', '2.809'],
#  [15, 5, 2, 17, 5, 4, '+1 prefetcher', 'LFU', 'LIP.', '2.810'],
#  [15, 5, 2, 17, 5, 3, '+1 prefetcher', 'LRU', 'MIP.', '2.816'],
#  [15, 5, 2, 17, 5, 3, '+1 prefetcher', 'LFU', 'MIP.', '2.816'],
#  [15, 5, 2, 17, 5, 3, '+1 prefetcher', 'LFU', 'LIP.', '2.817'],
#  [15, 5, 2, 17, 5, 2, '+1 prefetcher', 'LRU', 'LIP.', '2.830'],
#  [15, 5, 2, 17, 5, 2, '+1 prefetcher', 'LFU', 'MIP.', '2.835'],
#  [15, 5, 2, 17, 5, 2, '+1 prefetcher', 'LFU', 'LIP.', '2.835'],
#  [15, 6, 0, 17, 6, 5, '+1 prefetcher', 'LRU', 'LIP.', '2.836'],
#  [15, 5, 2, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '2.838'],
#  [15, 6, 0, 17, 6, 4, '+1 prefetcher', 'LRU', 'LIP.', '2.838'],
#  [15, 6, 0, 17, 6, 5, '+1 prefetcher', 'LRU', 'MIP.', '2.842'],
#  [15, 6, 0, 17, 6, 3, '+1 prefetcher', 'LRU', 'LIP.', '2.847'],
#  [15, 6, 0, 17, 6, 4, '+1 prefetcher', 'LRU', 'MIP.', '2.848'],
#  [15, 6, 0, 17, 6, 3, '+1 prefetcher', 'LRU', 'MIP.', '2.858'],
#  [15, 6, 0, 17, 6, 2, '+1 prefetcher', 'LRU', 'LIP.', '2.872'],
#  [15, 5, 2, 17, 5, 5, 'Strided prefetcher', 'LRU', 'LIP.', '2.879'],
#  [15, 5, 2, 17, 5, 4, 'Strided prefetcher', 'LRU', 'LIP.', '2.880'],
#  [15, 6, 0, 17, 6, 2, '+1 prefetcher', 'LRU', 'MIP.', '2.882'],
#  [15, 5, 2, 17, 5, 5, 'Strided prefetcher', 'LFU', 'MIP.', '2.890'],
#  [15, 5, 2, 17, 5, 5, 'Strided prefetcher', 'LFU', 'LIP.', '2.891'],
#  [15, 5, 2, 17, 5, 4, 'Strided prefetcher', 'LFU', 'MIP.', '2.893'],
#  [15, 5, 2, 17, 5, 4, 'Strided prefetcher', 'LFU', 'LIP.', '2.894'],
#  [15, 5, 2, 17, 5, 3, 'Strided prefetcher', 'LRU', 'LIP.', '2.895'],
#  [15, 5, 2, 17, 5, 3, 'Strided prefetcher', 'LFU', 'MIP.', '2.902'],
#  [15, 6, 0, 17, 6, 5, 'Strided prefetcher', 'LRU', 'LIP.', '2.902'],
#  [15, 5, 2, 17, 5, 3, 'Strided prefetcher', 'LFU', 'LIP.', '2.903'],
#  [15, 6, 0, 17, 6, 4, 'Strided prefetcher', 'LRU', 'LIP.', '2.907'],
#  [15, 5, 2, 17, 5, 5, 'Strided prefetcher', 'LRU', 'MIP.', '2.919'],
#  [15, 5, 2, 17, 5, 2, 'Strided prefetcher', 'LRU', 'LIP.', '2.920'],
#  [15, 6, 0, 17, 6, 3, 'Strided prefetcher', 'LRU', 'LIP.', '2.920'],
#  [15, 5, 2, 17, 5, 2, 'Strided prefetcher', 'LFU', 'LIP.', '2.923'],
#  [15, 5, 2, 17, 5, 4, 'Strided prefetcher', 'LRU', 'MIP.', '2.923'],
#  [15, 5, 2, 17, 5, 2, 'Strided prefetcher', 'LFU', 'MIP.', '2.928'],
#  [15, 5, 2, 17, 5, 3, 'Strided prefetcher', 'LRU', 'MIP.', '2.939'],
#  [15, 6, 0, 17, 6, 2, 'Strided prefetcher', 'LRU', 'LIP.', '2.945'],
#  [15, 6, 0, 17, 6, 4, 'Strided prefetcher', 'LRU', 'MIP.', '2.945'],
#  [15, 6, 0, 17, 6, 5, 'Strided prefetcher', 'LRU', 'MIP.', '2.945'],
#  [15,
#   6,
#   0,
#   17,
#   6,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.957'],
#  [15, 6, 0, 17, 6, 3, 'Strided prefetcher', 'LRU', 'MIP.', '2.960'],
#  [15, 5, 1, 17, 5, 5, '+1 prefetcher', 'LFU', 'MIP.', '2.963'],
#  [15, 5, 1, 17, 5, 5, '+1 prefetcher', 'LRU', 'LIP.', '2.963'],
#  [15, 5, 1, 17, 5, 5, '+1 prefetcher', 'LFU', 'LIP.', '2.963'],
#  [15, 5, 2, 17, 5, 2, 'Strided prefetcher', 'LRU', 'MIP.', '2.963'],
#  [15,
#   6,
#   0,
#   17,
#   6,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.963'],
#  [15, 5, 1, 17, 5, 4, '+1 prefetcher', 'LRU', 'LIP.', '2.966'],
#  [15, 5, 1, 17, 5, 5, '+1 prefetcher', 'LRU', 'MIP.', '2.966'],
#  [15, 5, 1, 17, 5, 4, '+1 prefetcher', 'LFU', 'MIP.', '2.967'],
#  [15, 5, 1, 17, 5, 4, '+1 prefetcher', 'LFU', 'LIP.', '2.967'],
#  [15, 5, 1, 17, 5, 4, '+1 prefetcher', 'LRU', 'MIP.', '2.969'],
#  [15, 5, 1, 17, 5, 3, '+1 prefetcher', 'LFU', 'MIP.', '2.974'],
#  [15, 5, 1, 17, 5, 3, '+1 prefetcher', 'LFU', 'LIP.', '2.974'],
#  [15,
#   6,
#   0,
#   17,
#   6,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.974'],
#  [15, 5, 1, 17, 5, 3, '+1 prefetcher', 'LRU', 'LIP.', '2.977'],
#  [15, 5, 1, 17, 5, 3, '+1 prefetcher', 'LRU', 'MIP.', '2.982'],
#  [15, 6, 0, 17, 6, 2, 'Strided prefetcher', 'LRU', 'MIP.', '2.988'],
#  [15,
#   6,
#   0,
#   17,
#   6,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '2.998'],
#  [15, 5, 1, 17, 5, 2, '+1 prefetcher', 'LRU', 'LIP.', '3.000'],
#  [15, 5, 1, 17, 5, 2, '+1 prefetcher', 'LFU', 'LIP.', '3.003'],
#  [15, 5, 1, 17, 5, 2, '+1 prefetcher', 'LFU', 'MIP.', '3.004'],
#  [15, 5, 1, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.006'],
#  [15,
#   5,
#   2,
#   17,
#   5,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.020'],
#  [15,
#   5,
#   2,
#   17,
#   5,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.022'],
#  [15,
#   5,
#   2,
#   17,
#   5,
#   5,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '3.036'],
#  [15,
#   5,
#   2,
#   17,
#   5,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.037'],
#  [15,
#   5,
#   2,
#   17,
#   5,
#   4,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '3.039'],
#  [15, 5, 1, 17, 5, 5, 'Strided prefetcher', 'LFU', 'MIP.', '3.046'],
#  [15, 5, 1, 17, 5, 5, 'Strided prefetcher', 'LFU', 'LIP.', '3.046'],
#  [15,
#   5,
#   2,
#   17,
#   5,
#   3,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '3.046'],
#  [15, 5, 1, 17, 5, 4, 'Strided prefetcher', 'LFU', 'MIP.', '3.050'],
#  [15, 5, 1, 17, 5, 5, 'Strided prefetcher', 'LRU', 'LIP.', '3.050'],
#  [15, 5, 1, 17, 5, 4, 'Strided prefetcher', 'LFU', 'LIP.', '3.051'],
#  [15, 5, 1, 17, 5, 4, 'Strided prefetcher', 'LRU', 'LIP.', '3.052'],
#  [15,
#   5,
#   2,
#   17,
#   5,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.055'],
#  [15, 5, 1, 17, 5, 3, 'Strided prefetcher', 'LFU', 'LIP.', '3.061'],
#  [15,
#   5,
#   2,
#   17,
#   5,
#   2,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '3.061'],
#  [15, 5, 1, 17, 5, 3, 'Strided prefetcher', 'LFU', 'MIP.', '3.062'],
#  [15, 5, 1, 17, 5, 3, 'Strided prefetcher', 'LRU', 'LIP.', '3.063'],
#  [15, 5, 1, 17, 5, 5, 'Strided prefetcher', 'LRU', 'MIP.', '3.086'],
#  [15, 5, 1, 17, 5, 4, 'Strided prefetcher', 'LRU', 'MIP.', '3.087'],
#  [15, 5, 1, 17, 5, 2, 'Strided prefetcher', 'LRU', 'LIP.', '3.091'],
#  [15, 5, 1, 17, 5, 2, 'Strided prefetcher', 'LFU', 'LIP.', '3.095'],
#  [15, 5, 1, 17, 5, 2, 'Strided prefetcher', 'LFU', 'MIP.', '3.103'],
#  [15, 5, 1, 17, 5, 3, 'Strided prefetcher', 'LRU', 'MIP.', '3.103'],
#  [15, 5, 1, 17, 5, 2, 'Strided prefetcher', 'LRU', 'MIP.', '3.135'],
#  [15,
#   5,
#   1,
#   17,
#   5,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.191'],
#  [15,
#   5,
#   1,
#   17,
#   5,
#   5,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '3.192'],
#  [15, 5, 0, 17, 5, 5, '+1 prefetcher', 'LRU', 'LIP.', '3.194'],
#  [15,
#   5,
#   1,
#   17,
#   5,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.194'],
#  [15, 5, 0, 17, 5, 5, '+1 prefetcher', 'LRU', 'MIP.', '3.196'],
#  [15,
#   5,
#   1,
#   17,
#   5,
#   4,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '3.196'],
#  [15, 5, 0, 17, 5, 4, '+1 prefetcher', 'LRU', 'LIP.', '3.197'],
#  [15, 5, 0, 17, 5, 4, '+1 prefetcher', 'LRU', 'MIP.', '3.200'],
#  [15,
#   5,
#   1,
#   17,
#   5,
#   3,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '3.203'],
#  [15,
#   5,
#   1,
#   17,
#   5,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.205'],
#  [15, 5, 0, 17, 5, 3, '+1 prefetcher', 'LRU', 'LIP.', '3.207'],
#  [15, 5, 0, 17, 5, 3, '+1 prefetcher', 'LRU', 'MIP.', '3.213'],
#  [15,
#   5,
#   1,
#   17,
#   5,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.227'],
#  [15,
#   5,
#   1,
#   17,
#   5,
#   2,
#   'Prefetcher disabled.',
#   'LFU',
#   'Prefetcher disabled.',
#   '3.228'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'LIP.', '3.230'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.235'],
#  [15, 5, 0, 17, 5, 5, 'Strided prefetcher', 'LRU', 'LIP.', '3.280'],
#  [15, 5, 0, 17, 5, 4, 'Strided prefetcher', 'LRU', 'LIP.', '3.282'],
#  [15, 5, 0, 17, 5, 3, 'Strided prefetcher', 'LRU', 'LIP.', '3.294'],
#  [15, 5, 0, 17, 5, 5, 'Strided prefetcher', 'LRU', 'MIP.', '3.314'],
#  [15, 5, 0, 17, 5, 4, 'Strided prefetcher', 'LRU', 'MIP.', '3.317'],
#  [15, 5, 0, 17, 5, 2, 'Strided prefetcher', 'LRU', 'LIP.', '3.321'],
#  [15, 5, 0, 17, 5, 3, 'Strided prefetcher', 'LRU', 'MIP.', '3.330'],
#  [15, 5, 0, 17, 5, 2, 'Strided prefetcher', 'LRU', 'MIP.', '3.358'],
#  [15,
#   5,
#   0,
#   17,
#   5,
#   5,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.422'],
#  [15,
#   5,
#   0,
#   17,
#   5,
#   4,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.425'],
#  [15,
#   5,
#   0,
#   17,
#   5,
#   3,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.435'],
#  [15,
#   5,
#   0,
#   17,
#   5,
#   2,
#   'Prefetcher disabled.',
#   'LRU',
#   'Prefetcher disabled.',
#   '3.456']]

# %%
data_list[:20]
# Out:
# [[15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.456'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.235'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.358'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.230'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.321'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.435'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.213'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.330'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.207'],
#  [15, 5, 0, 17, 5, 2, '+1 prefetcher', 'LRU', 'MIP.', '3.294']]
